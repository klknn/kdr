# %%
import numpy as np
import matplotlib.pyplot as plt
import pedalboard as pb

vst = pb.load_plugin("C:/Program Files/Common Files/VST3/OTT.vst3")
vst.parameters.keys()
# Out:
# dict_keys(['depth', 'time', 'in_gain_db', 'out_gain_db', 'clean_xov', 'thresh_l', 'thresh_m', 'thresh_h', 'gain_l_db', 'gain_m_db', 'gain_h_db', 'byp_upwd_l', 'byp_upwd_m', 'byp_upwd_h', 'byp_dnwd_l', 'byp_dnwd_m', 'byp_dnwd_h', 'upwd_strgth', 'dnwd_strgth', 'bypass', 'program'])

# %%
sr = 44100
x = np.linspace(0, 0.1, 100000)
y = vst(x, sample_rate=sr)

plt.plot(x, x, label="x")
plt.plot(x, y, label="y")
plt.legend()
plt.grid()

# %%
vst.parameters
# Out:
# {'depth': <pedalboard.AudioProcessorParameter name="Depth" label="%" discrete raw_value=1 value=100 range=(0.0, 100.0, 1.0)>,
#  'time': <pedalboard.AudioProcessorParameter name="Time" label="%" discrete raw_value=0.5 value=100 range=(0.0, 1000.0, ~1.5)>,
#  'in_gain_db': <pedalboard.AudioProcessorParameter name="In Gain" label="dB" discrete raw_value=0.5 value=0.0 range=(-54.0, 19.1, ~1.3111111111111111)>,
#  'out_gain_db': <pedalboard.AudioProcessorParameter name="Out Gain" label="dB" discrete raw_value=0.5 value=0.0 range=(-54.0, 19.1, ~1.3111111111111111)>,
#  'clean_xov': <pedalboard.AudioProcessorParameter name="Clean XOV" discrete raw_value=0 value=OFF boolean ("False" and "True")>,
#  'thresh_l': <pedalboard.AudioProcessorParameter name="Thresh L" label="%" discrete raw_value=0.5 value=100 range=(0.0, 200.0, 1.0)>,
#  'thresh_m': <pedalboard.AudioProcessorParameter name="Thresh M" label="%" discrete raw_value=0.5 value=100 range=(0.0, 200.0, 1.0)>,
#  'thresh_h': <pedalboard.AudioProcessorParameter name="Thresh H" label="%" discrete raw_value=0.5 value=100 range=(0.0, 200.0, 1.0)>,
#  'gain_l_db': <pedalboard.AudioProcessorParameter name="Gain L" label="dB" discrete raw_value=0.5 value=0.0 range=(-inf, 6.0, ~inf)>,
#  'gain_m_db': <pedalboard.AudioProcessorParameter name="Gain M" label="dB" discrete raw_value=0.5 value=0.0 range=(-inf, 6.0, ~inf)>,
#  'gain_h_db': <pedalboard.AudioProcessorParameter name="Gain H" label="dB" discrete raw_value=0.5 value=0.0 range=(-inf, 6.0, ~inf)>,
#  'byp_upwd_l': <pedalboard.AudioProcessorParameter name="Byp Upwd L" discrete raw_value=0 value="--" (2 valid string values)>,
#  'byp_upwd_m': <pedalboard.AudioProcessorParameter name="Byp Upwd M" discrete raw_value=0 value="--" (2 valid string values)>,
#  'byp_upwd_h': <pedalboard.AudioProcessorParameter name="Byp Upwd H" discrete raw_value=0 value="--" (2 valid string values)>,
#  'byp_dnwd_l': <pedalboard.AudioProcessorParameter name="Byp Dnwd L" discrete raw_value=0 value="--" (1 valid string value)>,
#  'byp_dnwd_m': <pedalboard.AudioProcessorParameter name="Byp Dnwd M" discrete raw_value=0 value="--" (1 valid string value)>,
#  'byp_dnwd_h': <pedalboard.AudioProcessorParameter name="Byp Dnwd H" discrete raw_value=0 value="--" (1 valid string value)>,
#  'upwd_strgth': <pedalboard.AudioProcessorParameter name="Upwd Strgth" label="%" discrete raw_value=0.5 value=100 range=(0.0, 200.0, 1.0)>,
#  'dnwd_strgth': <pedalboard.AudioProcessorParameter name="Dnwd Strgth" label="%" discrete raw_value=0.5 value=100 range=(0.0, 200.0, 1.0)>,
#  'bypass': <pedalboard.AudioProcessorParameter name="Bypass" discrete raw_value=0 value="--" (2 valid string values)>,
#  'program': <pedalboard.AudioProcessorParameter name="Program" discrete raw_value=0 value=1 range=(1.0, 2.0, 1.0)>}
